# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulwasaeee/Recurrent-Neural-Network/blob/main/Embedding_Implemenation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent=['the glass of milk',
      'the glasss of juice',
      'the cup of tea',
      'i am a good boy',
      'i am a good developer',
      'understand the meaning of words',
      'the videos are good'
]

# %%
vocabsize=10000

# %%
onehotrep=[one_hot(words,vocabsize) for words in sent]
onehotrep
# Out:
# [[2424, 401, 286, 7887],
#  [2424, 8855, 286, 6252],
#  [2424, 446, 286, 1676],
#  [5748, 9887, 9421, 5124, 2177],
#  [5748, 9887, 9421, 5124, 4665],
#  [9027, 2424, 529, 286, 3019],
#  [2424, 150, 8592, 5124]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sentlength=8
embedrep=pad_sequences(onehotrep,padding='pre',maxlen=sent_length)
embedrep
# Out:
# array([[   0,    0,    0,    0, 2424,  401,  286, 7887],
#        [   0,    0,    0,    0, 2424, 8855,  286, 6252],
#        [   0,    0,    0,    0, 2424,  446,  286, 1676],
#        [   0,    0,    0, 5748, 9887, 9421, 5124, 2177],
#        [   0,    0,    0, 5748, 9887, 9421, 5124, 4665],
#        [   0,    0,    0, 9027, 2424,  529,  286, 3019],
#        [   0,    0,    0,    0, 2424,  150, 8592, 5124]], dtype=int32)

# %%
dim=10

# %%
model=Sequential([
    Embedding(vocabsize,dim,input_length=sentlength)
])

# %%
model.compile(optimizer='adam',loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedrep)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# array([[[ 9.24505293e-04, -3.00988089e-02,  8.32412392e-03,
#           3.57069708e-02, -3.89706120e-02, -4.30763848e-02,
#          -2.75753625e-02,  4.46034931e-02, -1.53565295e-02,
#           1.37654059e-02],
#         [ 9.24505293e-04, -3.00988089e-02,  8.32412392e-03,
#           3.57069708e-02, -3.89706120e-02, -4.30763848e-02,
#          -2.75753625e-02,  4.46034931e-02, -1.53565295e-02,
#           1.37654059e-02],
#         [ 9.24505293e-04, -3.00988089e-02,  8.32412392e-03,
#           3.57069708e-02, -3.89706120e-02, -4.30763848e-02,
#          -2.75753625e-02,  4.46034931e-02, -1.53565295e-02,
#           1.37654059e-02],
#         [ 9.24505293e-04, -3.00988089e-02,  8.32412392e-03,
#           3.57069708e-02, -3.89706120e-02, -4.30763848e-02,
#          -2.75753625e-02,  4.46034931e-02, -1.53565295e-02,
#           1.37654059e-02],
#         [ 4.48492654e-02,  4.69796769e-02, -4.79307547e-02,
# ...
